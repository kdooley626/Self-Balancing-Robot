# %% [markdown]
# # Work Log
# ## 8/29
# ### Status
# Motor Deadband
# | Motor | Direction | Minimum Speed |
# | ---   | ---       | ---           |
# | Left  | Forward   | 155           |
# | Left  | Backward  | 150           |
# | Right | Forward   | 150           |
# | Right | Backward  | 155           |
#
# Balance Time
# | Trial | Time [s] |
# | 1.    | 1.3      |
# | 2.    | 1.93     |
#
# ### Observations
# - Robot can stay up if the chord to the ESP32 is held in such a way to restrian tipping a bit and keep the chord from pulling on the robot
# - Robot loses balance when it runs away
# - Difficult to get an accurate time because user holds robot up and then lets go to see if it balances, there is no procedure yet to support the robot then remove supports and assess balancing
#     - Balance initiation sequence could be a potential upgrade (an actuated kick stand or standing mechanism could engage or disengage depending on if the robot is at rest or balancing)
# ### Current issues:
# Balance cannot last more than a few seconds \
# Potential causes:
# - Charging/flashing cable for ESP32 affecting balance
#     - Currently using cable connected to laptop to charge and flash to ESP32 and cable restricts movement and affects balance
#     - Solution: Connect buck converter to battery pack directly to charge ESP32
#     - Set up WIFI connection to ESPew to flash scripts over WIFI
# - Motor deadband too large, limiting the range for the controller inputs
